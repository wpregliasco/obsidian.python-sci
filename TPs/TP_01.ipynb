# %% [markdown]
# # Aeropuerto Bariloche
#
# bla
#
# ## Carga de datos

# %%
# archivo
f=open('SAZS_2020_2026.csv', 'rt')
data = f.read()
f.close()

print(len(data), type(data))
print('-'*70)
print(data[:700])
# Out:
# 4825294 <class 'str'>
# ----------------------------------------------------------------------
# station,date,timestamp,lon,lat,elevation,temp,dewpt,wind_dir,wind_speed,press
# SAZS,2020-01-01 00:00,1577847600.0,-71.1575,-41.1512,840.00,23.0,7.0,270.0,7.0,1015.0
# SAZS,2020-01-01 01:00,1577851200.0,-71.1575,-41.1512,840.00,21.0,8.0,270.0,6.0,1015.0
# SAZS,2020-01-01 02:00,1577854800.0,-71.1575,-41.1512,840.00,17.0,7.0,140.0,4.0,1016.0
# SAZS,2020-01-01 03:00,1577858400.0,-71.1575,-41.1512,840.00,16.0,7.0,140.0,4.0,1016.0
# SAZS,2020-01-01 04:00,1577862000.0,-71.1575,-41.1512,840.00,15.0,7.0,180.0,5.0,1016.0
# SAZS,2020-01-01 05:00,1577865600.0,-71.1575,-41.1512,840.00,15.0,6.0,180.0,5.0,1017.0
# SAZS,2020-01-01 06:00,1577869200.0,-71.1575,-41.1512,840.00,15.0,5.0,180.0,7.0,1016.0
# SAZS,2020-01-01 07:0

# %%
# Separación en líneas
data_lines = data.split('\n')
print(len(data_lines), type(data_lines))
print('-'*70)
print(data_lines[0])
print(data_lines[1])
# Out:
# 55914 <class 'list'>
# ----------------------------------------------------------------------
# station,date,timestamp,lon,lat,elevation,temp,dewpt,wind_dir,wind_speed,press
# SAZS,2020-01-01 00:00,1577847600.0,-71.1575,-41.1512,840.00,23.0,7.0,270.0,7.0,1015.0

# %%
# Lectura del header por separado
headers = data_lines[0].split(',')
print(len(headers), type(headers))
print('-'*70)
print(headers)
# Out:
# 11 <class 'list'>
# ----------------------------------------------------------------------
# ['station', 'date', 'timestamp', 'lon', 'lat', 'elevation', 'temp', 'dewpt', 'wind_dir', 'wind_speed', 'press']

# %%
# Tiempos, uso timestampas que son segundo desde 1970-01-01
#
timestamp = []
for row in range(1, len(data_lines)):
    timestamp.append(data_lines[row].split(',')[2])


for item in timestamp[:10]:
    print(item)
# Out:
# 1577847600.0
# 1577851200.0
# 1577854800.0
# 1577858400.0
# 1577862000.0
# 1577865600.0
# 1577869200.0
# 1577872800.0
# 1577876400.0
# 1577880000.0

# %%
# Temperatura
#
temp = []
for row in range(1, len(data_lines)):
    temp.append(data_lines[row].split(',')[6])

for item in temp[:10]:
    print(item)
# Out:
# 23.0
# 21.0
# 17.0
# 16.0
# 15.0
# 15.0
# 15.0
# 14.0
# 14.0
# 14.0

# %%
# Persión atmosférica
#
press = []
for row in range(1, len(data_lines)):
    press.append(data_lines[row].split(',')[10])

for item in press[:10]:
    print(item)
# Out:
# 1015.0
# 1015.0
# 1016.0
# 1016.0
# 1016.0
# 1017.0
# 1016.0
# 1016.0
# 1016.0
# 1016.0

# %%
# Son todos los datos compatibles, tengo los mismos 
# cantidad datos en cada lista?

print(len(timestamp), len(temp), len(press))
# Out:
# 55913 55913 55913

# %% [markdown]
# ## Acondicionamiento de los datos
#
# Vamos a convertir los datos en variables graficables.
# Por aha son sólo strings de texto.

# %%
# Convierto los datos a numeros,
# hasta ahora son cadenas de caracteres


buffer = []

for item in timestamp:
	buffer.append(float(item))

timestamp = buffer

buffer = []

for item in temp:
	buffer.append(float(item))
  
temp = buffer

buffer = []

for item in press:
	buffer.append(float(item))

press = buffer
  
print(len(timestamp), len(temp), len(press))
# Out:
# 55913 55913 55913

# %%
import matplotlib.pyplot as plt
 

plt.plot(temp[0:48], "o-")
plt.show()
